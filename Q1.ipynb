# %%
print("Read the csv file and import some libraries.")
print("and, to show first eleven rows in csv file :")
# Out:
# Read the csv file and import some libraries.
# and, to show first eleven rows in csv file :

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sb
from scipy import stats
from scipy.stats import skew,kurtosis, probplot
from statsmodels.formula.api import ols  
import statsmodels.api as sm  
import probscale

ingredient = pd.read_csv('ingredient.csv')
#ingredient.head()
ingredient[:11]
# Out:
#           a      b     c     d      e     f      g     h     i
# 0   1.51735  13.02  3.54  1.69  72.73  0.54   8.44  0.00  0.07
# 1   1.53125  10.73  0.00  2.10  69.81  0.58  13.30  3.15  0.28
# 2   1.52300  13.31  3.58  0.82  71.99  0.12  10.17  0.00  0.03
# 3   1.51768  12.56  3.52  1.43  73.15  0.57   8.54  0.00  0.00
# 4   1.51813  13.43  3.98  1.18  72.49  0.58   8.15  0.00  0.00
# 5   1.51721  12.87  3.48  1.33  73.04  0.56   8.43  0.00  0.00
# 6   1.51596  12.79  3.61  1.62  72.97  0.64   8.07  0.00  0.26
# 7   1.51316  13.02  0.00  3.04  70.48  6.21   6.96  0.00  0.00
# 8   1.51747  12.84  3.50  1.14  73.27  0.56   8.55  0.00  0.00
# 9   1.52121  14.03  3.76  0.58  71.79  0.11   9.65  0.00  0.00
# 10  1.51736  12.78  3.62  1.29  72.79  0.59   8.70  0.00  0.00

# %%
print("_ to show number of columns and number of rows :")
# Out:
# _ to show number of columns and number of rows :

# %%
ingredient.shape
# Out:
# (214, 9)

# %%
print("_ To show the type, non-Null, and name of the columns :")
# Out:
# _ To show the type, non-Null, and name of the columns :

# %%
ingredient.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 214 entries, 0 to 213
# Data columns (total 9 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   a       214 non-null    float64
#  1   b       214 non-null    float64
#  2   c       214 non-null    float64
#  3   d       214 non-null    float64
#  4   e       214 non-null    float64
#  5   f       214 non-null    float64
#  6   g       214 non-null    float64
#  7   h       214 non-null    float64
#  8   i       214 non-null    float64
# dtypes: float64(9)
# memory usage: 15.2 KB

# %%
print("_ To show the difference in the number of values in each column: ")
# Out:
# _ To show the difference in the number of values in each column:

# %%
ingredient.nunique()
# Out:
# a    178
# b    142
# c     94
# d    118
# e    133
# f     65
# g    143
# h     34
# i     32
# dtype: int64

# %%
print("_ To describe our data set , like  mean , minimum , maximum , standard deviation, count , first_second_third quartile  methods")
# Out:
# _ To describe our data set , like  mean , minimum , maximum , standard deviation, count , first_second_third quartile  methods

# %%
ingredient.describe()
# Out:
#                 a           b           c           d           e           f  \
# count  214.000000  214.000000  214.000000  214.000000  214.000000  214.000000
# mean     1.518365   13.407850    2.684533    1.444907   72.650935    0.497056
# std      0.003037    0.816604    1.442408    0.499270    0.774546    0.652192
# min      1.511150   10.730000    0.000000    0.290000   69.810000    0.000000
# 25%      1.516522   12.907500    2.115000    1.190000   72.280000    0.122500
# 50%      1.517680   13.300000    3.480000    1.360000   72.790000    0.555000
# 75%      1.519157   13.825000    3.600000    1.630000   73.087500    0.610000
# max      1.533930   17.380000    4.490000    3.500000   75.410000    6.210000
#
#                 g           h           i
# count  214.000000  214.000000  214.000000
# mean     8.956963    0.175047    0.057009
# std      1.423153    0.497219    0.097439
# min      5.430000    0.000000    0.000000
# 25%      8.240000    0.000000    0.000000
# ...

# %%
print("_ To showing how much each Column have  skewed")
# Out:
# _ To showing how much each Column have  skewed

# %%
skew(ingredient, axis = 0)
# Out:
# array([ 1.61401505,  0.45099172, -1.14446485,  0.90091788, -0.72531727,
#         6.50563583,  2.03267738,  3.39243089,  1.74200676])

# %%
print("_ To draw histogram for analyze data set :")
# Out:
# _ To draw histogram for analyze data set :

# %%
fig, ax = plt.subplots(figsize=(5, 4))
ax = sb.histplot(ingredient['a'], kde=True, stat="density", color="red")
plt.show()

# %%
bx = sb.histplot(ingredient['b'], kde=True, stat="density", color="red")

# %%
cx = sb.histplot(ingredient['c'], kde=True, stat="density", color="red")

# %%
dx = sb.histplot(ingredient['d'], kde=True, stat="density", color="red")

# %%
ex = sb.histplot(ingredient['e'], kde=True, stat="density", color="red")

# %%
fx = sb.histplot(ingredient['f'], kde=True, stat="density", color="red")

# %%
gx = sb.histplot(ingredient['g'], kde=True, stat="density", color="red")

# %%
hx = sb.histplot(ingredient['h'], kde=True, stat="density", color="red")

# %%
ix = sb.histplot(ingredient['i'], kde=True, stat="density", color="red")

# %%
print("_ Now, by looking at the histograms, it can be said that columns ( a - b - d - e - f - g  -  h -  i ) have parametric data except for column C")
# Out:
# _ Now, by looking at the histograms, it can be said that columns ( a - b - d - e - f - g  -  h -  i ) have parametric data except for column C

# %%
model = ols(
    'a ~ b + c + d + e + f + g + h + i', data = ingredient).fit()
sm.stats.anova_lm(model, typ=2) 
# performing type 2 anova test  
aovtable = sm.stats.anova_lm(model, typ = 2)   
print('ANOVA Table for "a" with "b, c, d, e, f, g, h, i"')  
print(aovtable)  
print()
# Out:
# ANOVA Table for "a" with "b, c, d, e, f, g, h, i"
#                 sum_sq     df          F    PR(>F)
# b         4.574068e-06    1.0   4.536899  0.034364
# c         7.515654e-06    1.0   7.454582  0.006878
# d         2.200281e-09    1.0   0.002182  0.962785
# e         6.238561e-08    1.0   0.061879  0.803800
# f         4.049714e-06    1.0   4.016807  0.046365
# g         2.192379e-05    1.0  21.745638  0.000006
# h         1.962916e-05    1.0  19.469652  0.000017
# i         3.021286e-07    1.0   0.299674  0.584683
# Residual  2.066795e-04  205.0        NaN       NaN

# %%
print("_ To show correlation matrix :")
print("_  correlation features between columns 'a' and'g' are extremely high while 'a' and 'c, i' are significantly low")
# Out:
# _ To show correlation matrix :
# _  correlation features between columns 'a' and'g' are extremely high while 'a' and 'c, i' are significantly low

# %%
plt.figure(figsize = (10, 10))
ax = sb.heatmap(
    ingredient.corr(),
    vmin=-1,
    vmax=1,
    square=True,
    linewidth=0.5,
    cmap="coolwarm_r",
    annot=True,
)
ax.set_yticklabels(ax.get_yticklabels(), rotation=0)
ax.set(title="Correlation matrix (Pearson's r)")

plt.tight_layout()
plt.show()

# %%
print("_ graphical analysis")
print("_ To show Display graphical analysis that each column how much have  skewed ")
# Out:
# _ graphical analysis
# _ To show Display graphical analysis that each column how much have  skewed

# %%
print()
print("this graph can be considered as normal and a bit right skewed")
print()
ingredient["a"].plot.box(figsize=(4, 6))
# Out:
# this graph can be considered as normal and a bit right skewed
# <AxesSubplot:>

# %%
print()
print("this graph can be considered as normal and a bit left skewed")
print()
ingredient["b"].plot.box(figsize=(4, 6))
# Out:
# this graph can be considered as normal and a bit left skewed
# <AxesSubplot:>

# %%
print()
print("this graph can be considered as normal and to a great extent left skewed")
print()
ingredient["c"].plot.box(figsize=(4, 6))
# Out:
# this graph can be considered as normal and to a great extent left skewed
# <AxesSubplot:>

# %%
print()
print("this graph can be considered as normal and a bit left skewed")
print()
ingredient["d"].plot.box(figsize=(4, 6))
# Out:
# this graph can be considered as normal and a bit left skewed
# <AxesSubplot:>

# %%
print()
print("this graph can be considered as normal and right skewed")
print()
ingredient["e"].plot.box(figsize=(4, 6))
# Out:
# this graph can be considered as normal and right skewed
# <AxesSubplot:>

# %%
print()
print("this graph can be considered as normal and right skewed")
print()
ingredient["f"].plot.box(figsize=(4, 6))
# Out:
# this graph can be considered as normal and right skewed
# <AxesSubplot:>

# %%
print()
print("this graph can be considered as normal and left skewed")
print()
ingredient["g"].plot.box(figsize=(4, 6))
# Out:
# this graph can be considered as normal and left skewed
# <AxesSubplot:>

# %%
print()
print("this graph it is not normal because there are a lots of outliners.")
print()
ingredient["h"].plot.box(figsize=(4, 6))
# Out:
# this graph it is not normal because there are a lots of outliners.
# <AxesSubplot:>

# %%
print()
print("this graph it is not normal because there are a lots of outliners.")
print()
ingredient["i"].plot.box(figsize=(4, 6))
# Out:
# this graph it is not normal because there are a lots of outliners.
# <AxesSubplot:>

# %%
fig, ax = plt.subplots(figsize=(10, 3))
fig = probscale.probplot(ingredient["a"], ax=ax, plottype='prob', datascale='log', problabel='Standard Normal Quantiles', color="red")

# %%
fig, ax = plt.subplots(figsize=(10, 3))
fig = probscale.probplot(ingredient["b"], ax=ax, plottype='prob', datascale='log', problabel='Standard Normal Quantiles',color="red")

# %%
fig, ax = plt.subplots(figsize=(10, 3))
fig = probscale.probplot(ingredient["c"], ax=ax, plottype='prob', datascale='log', problabel='Standard Normal Quantiles', color="red")

# %%
fig, ax = plt.subplots(figsize=(10, 3))
fig = probscale.probplot(ingredient["d"], ax=ax, plottype='prob', datascale='log', problabel='Standard Normal Quantiles', color="red")

# %%
fig, ax = plt.subplots(figsize=(10, 3))
fig = probscale.probplot(ingredient["e"], ax=ax, plottype='prob', datascale='log', problabel='Standard Normal Quantiles', color="red")

# %%
fig, ax = plt.subplots(figsize=(10, 3))
fig = probscale.probplot(ingredient["f"], ax=ax, plottype='prob', datascale='log', problabel='Standard Normal Quantiles',color="red")

# %%
fig, ax = plt.subplots(figsize=(10, 3))
fig = probscale.probplot(ingredient["g"], ax=ax, plottype='prob', datascale='log', problabel='Standard Normal Quantiles',color="red")

# %%
fig, ax = plt.subplots(figsize=(10, 3))
fig = probscale.probplot(ingredient["h"], ax=ax, plottype='prob', datascale='log', problabel='Standard Normal Quantiles',color="red")

# %%
fig, ax = plt.subplots(figsize=(10, 3))
fig = probscale.probplot(ingredient["i"], ax=ax, plottype='prob', datascale='log', problabel='Standard Normal Quantiles',color="red")

# %%
print("_ the columns  c , f , g , i  are not completely normally distributed.")
# Out:
# _ the columns  c , f , g , i  are not completely normally distributed.

# %%
print()
print("_ Clustering test ")
# Out:
# _ Clustering test

# %%
data_array = np.array(ingredient)

# %%
import matplotlib.pyplot as plt
from kneed import KneeLocator
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
scaled_data = scaler.fit_transform(data_array)

# %%
kmeans_kwargs = \
{
"init": "random",
"n_init": 10,
 "max_iter": 300,
"random_state": 42,
}


sse = []
for k in range(1, 11):
    kmeans = KMeans(n_clusters = k, **kmeans_kwargs)
    kmeans.fit(scaled_data)
    sse.append(kmeans.inertia_)
# Out:
# C:\Users\Danyal\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1036: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(

# %%
plt.style.use("fivethirtyeight")
plt.plot(range(1, 11), sse)
plt.xticks(range(1, 11))
plt.xlabel("Number of Clusters")
plt.ylabel("SSE")
plt.show()

# %%
kl = KneeLocator(range(1, 11), sse, curve="convex", direction="decreasing")

# %%
kl.elbow
# Out:
# 5

# %%
print("There are 5 differences in the formulation.")
# Out:
# There are 5 differences in the formulation.
